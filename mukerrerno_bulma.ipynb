# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd drive/
# %cd MyDrive/
# %cd Colab Notebooks/
# %cd TDDI2022/

# %ls
# Out:
# /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/Colab Notebooks
# /content/drive/MyDrive/Colab Notebooks/TDDI2022
# kanunum-nlp-doc-analysis-dataset.csv  modelTestSonuclari.txt

# %%
df = pd.read_csv('kanunum-nlp-doc-analysis-dataset.csv')
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4142 entries, 0 to 4141
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4142 non-null   int64
#  1   kategori        4142 non-null   object
#  2   baslik          4142 non-null   object
#  3   rega_no         2527 non-null   object
#  4   mukerrer_no     3642 non-null   float64
#  5   rega_tarihi     2527 non-null   object
#  6   kurum           2488 non-null   object
#  7   mevzuat_no      1091 non-null   object
#  8   belge_sayi      43 non-null     object
#  9   mevzuat_tarihi  1905 non-null   object
#  10  donem           500 non-null    object
#  11  sira_no         500 non-null    object
#  12  madde_sayisi    4142 non-null   int64
#  13  data_text       4142 non-null   object
#  14  url             4142 non-null   object
#  15  kanunum_url     4142 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 517.9+ KB

# %%
mukerrer_dogru=0
mukerrer_yanlis=0

for i in range(4142):
  metin = df['data_text'][i][:310].lower()

  if metin.find(". mükerrer") != -1:
      baslangic_mukerrer = metin.find(". mükerrer")
      mukerrer = int(metin[baslangic_mukerrer - 1])
  elif metin.find("mükerrer") != -1:
      mukerrer = 1
  else:
      mukerrer = 0
  
  mukerrer_df = df.loc[i]['mukerrer_no']
  if mukerrer_df != "NaN":
    mukerrer_df = 0
  else:
    mukerrer_df = mukerrer_df[0]

  if mukerrer == mukerrer_df:
      mukerrer_dogru += 1
  else:
      mukerrer_yanlis += 1
      print(i)
      print("*mukerrer_no* cevap:", mukerrer, " doğrusu:", df.loc[i]['mukerrer_no'])
print("D:", mukerrer_dogru, "Y:", mukerrer_yanlis)
# Out:
# 2
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 10
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 14
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 32
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 66
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 69
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 74
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 75
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 92
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 100
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 125
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 142
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 164
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 171
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 192
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 202
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 203
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 204
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 206
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 208
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 210
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 214
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 218
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 277
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 293
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 312
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 324
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 341
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 346
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 353
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 364
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 400
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 411
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 456
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 499
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 538
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 565
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 571
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 667
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 688
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 718
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 750
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 826
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 828
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 829
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 830
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 831
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 832
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 834
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 835
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 836
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 838
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 843
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 844
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 846
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 847
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 848
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 849
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 850
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 852
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 857
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 858
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 866
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 871
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 875
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 878
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 884
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 886
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 894
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 899
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 906
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 916
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 1087
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 1233
# *mukerrer_no* cevap: 2  doğrusu: 0.0
# 1248
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 1254
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 1816
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2019
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2087
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 2202
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2203
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2204
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2252
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 2287
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2342
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2369
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2425
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2432
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2438
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 2459
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2460
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 2542
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 2543
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2564
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 2567
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 2572
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2573
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2574
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2576
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2586
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2588
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2594
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2601
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 2646
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2649
# *mukerrer_no* cevap: 3  doğrusu: 0.0
# 2682
# *mukerrer_no* cevap: 3  doğrusu: 0.0
# 2698
# *mukerrer_no* cevap: 3  doğrusu: 0.0
# 2701
# *mukerrer_no* cevap: 4  doğrusu: 4.0
# 2704
# *mukerrer_no* cevap: 4  doğrusu: 4.0
# 2710
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2728
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 2734
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2749
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2755
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2756
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2768
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2770
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2771
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2778
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2797
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2801
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2802
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2804
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2806
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2807
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2808
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2817
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2818
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2819
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2820
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2826
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 2828
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 2829
# *mukerrer_no* cevap: 4  doğrusu: 4.0
# 2832
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2833
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2834
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2835
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2838
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2841
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2842
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2849
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2853
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2864
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2865
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2866
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2877
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 2908
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2925
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2927
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2931
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2934
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2936
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 2937
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 2938
# *mukerrer_no* cevap: 4  doğrusu: 4.0
# 2939
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 2940
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2941
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 2949
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2952
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 2963
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2982
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2991
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 2999
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3000
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3001
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3005
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 3006
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 3007
# *mukerrer_no* cevap: 4  doğrusu: 4.0
# 3022
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3023
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3024
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3033
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3038
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 3041
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3042
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3043
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3050
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3060
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3063
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3066
# *mukerrer_no* cevap: 2  doğrusu: 2.0
# 3067
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 3069
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 3070
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 3071
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 3073
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3077
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3078
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3082
# *mukerrer_no* cevap: 4  doğrusu: 4.0
# 3096
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3097
# *mukerrer_no* cevap: 6  doğrusu: 6.0
# 3104
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3134
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3141
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3149
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3152
# *mukerrer_no* cevap: 3  doğrusu: 3.0
# 3156
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3308
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3489
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3757
# *mukerrer_no* cevap: 1  doğrusu: 0.0
# 3782
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3848
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# 3935
# *mukerrer_no* cevap: 1  doğrusu: 1.0
# D: 3940 Y: 202
